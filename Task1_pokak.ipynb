# %% [markdown]
# Task-1

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler

# %%
df=pd.read_csv("/content/drive/MyDrive/tested.csv")
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ..                                            ...     ...   ...    ...    ...
# 413                            Spector, Mr. Woolf    male   NaN      0      0
# 414                  Oliva y Ocana, Dona. Fermina  female  39.0      0      0
# 415                  Saether, Mr. Simon Sivertsen    male  38.5      0      0
# 416                           Ware, Mr. Frederick    male   NaN      0      0
# 417                      Peter, Master. Michael J    male   NaN      1      1
#
#                  Ticket      Fare Cabin Embarked
# 0                330911    7.8292   NaN        Q
# 1                363272    7.0000   NaN        S
# 2                240276    9.6875   NaN        Q
# 3                315154    8.6625   NaN        S
# 4               3101298   12.2875   NaN        S
# ..                  ...       ...   ...      ...
# 413           A.5. 3236    8.0500   NaN        S
# 414            PC 17758  108.9000  C105        C
# 415  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416              359309    8.0500   NaN        S
# 417                2668   22.3583   NaN        C
#
# [418 rows x 12 columns]

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    object
#  4   Sex          418 non-null    object
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    object
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     object
#  11  Embarked     418 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 39.3+ KB

# %%
df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df['Age'].dtype
# Out:
# dtype('float64')

# %%
df['Fare'].dtype
# Out:
# dtype('float64')

# %%
df['Cabin'].dtype
# Out:
# dtype('O')

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %%
df.drop(columns=['Cabin'], inplace=True)

# %%
df.drop_duplicates(inplace=True)

# %%
df.replace(["?", "NA", "N/A", ""], np.nan, inplace=True)

# %%
num_cols = df.select_dtypes(include=["int64","float64"]).columns
cat_cols = df.select_dtypes(include=["object"]).columns
for col in num_cols:
    df[col].fillna(df[col].median(), inplace=True)
for col in cat_cols:
    df[col].fillna(df[col].mode()[0], inplace=True)
# Out:
# /tmp/ipython-input-3743677865.py:4: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].median(), inplace=True)
# /tmp/ipython-input-3743677865.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df[col].fillna(df[col].mode()[0], inplace=True)

# %%
df = pd.get_dummies(df, drop_first=True)

# %%
df = df.apply(pd.to_numeric)
df
# Out:
#      PassengerId  Survived  Pclass   Age  SibSp  Parch      Fare  \
# 0            892         0       3  34.5      0      0    7.8292
# 1            893         1       3  47.0      1      0    7.0000
# 2            894         0       2  62.0      0      0    9.6875
# 3            895         0       3  27.0      0      0    8.6625
# 4            896         1       3  22.0      1      1   12.2875
# ..           ...       ...     ...   ...    ...    ...       ...
# 413         1305         0       3  27.0      0      0    8.0500
# 414         1306         1       1  39.0      0      0  108.9000
# 415         1307         0       3  38.5      0      0    7.2500
# 416         1308         0       3  27.0      0      0    8.0500
# 417         1309         0       3  27.0      1      1   22.3583
#
#      Name_Abelseth, Miss. Karen Marie  Name_Abelseth, Mr. Olaus Jorgensen  \
# 0                               False                               False
# 1                               False                               False
# 2                               False                               False
# 3                               False                               False
# 4                               False                               False
# ..                                ...                                 ...
# 413                             False                               False
# 414                             False                               False
# 415                             False                               False
# 416                             False                               False
# 417                             False                               False
#
#      Name_Abrahamsson, Mr. Abraham August Johannes  ...  \
# 0                                            False  ...
# 1                                            False  ...
# 2                                            False  ...
# 3                                            False  ...
# 4                                            False  ...
# ..                                             ...  ...
# 413                                          False  ...
# 414                                          False  ...
# 415                                          False  ...
# 416                                          False  ...
# 417                                          False  ...
#
#      Ticket_STON/O 2. 3101291  Ticket_STON/O2. 3101270  \
# 0                       False                    False
# 1                       False                    False
# 2                       False                    False
# 3                       False                    False
# 4                       False                    False
# ..                        ...                      ...
# 413                     False                    False
# 414                     False                    False
# 415                     False                    False
# 416                     False                    False
# 417                     False                    False
#
#      Ticket_STON/OQ. 369943  Ticket_W./C. 14260  Ticket_W./C. 14266  \
# 0                     False               False               False
# 1                     False               False               False
# 2                     False               False               False
# 3                     False               False               False
# 4                     False               False               False
# ..                      ...                 ...                 ...
# 413                   False               False               False
# 414                   False               False               False
# 415                   False               False               False
# 416                   False               False               False
# 417                   False               False               False
#
#      Ticket_W./C. 6607  Ticket_W./C. 6608  Ticket_W.E.P. 5734  Embarked_Q  \
# 0                False              False               False        True
# 1                False              False               False       False
# 2                False              False               False        True
# 3                False              False               False       False
# 4                False              False               False       False
# ..                 ...                ...                 ...         ...
# 413              False              False               False       False
# 414              False              False               False       False
# 415              False              False               False       False
# 416              False              False               False       False
# 417              False              False               False       False
#
#      Embarked_S
# 0         False
# 1          True
# 2         False
# 3          True
# 4          True
# ..          ...
# 413        True
# 414       False
# 415        True
# 416        True
# 417       False
#
# [418 rows x 789 columns]

# %%
df.isna().sum()
# Out:
# PassengerId           0
# Survived              0
# Pclass                0
# Age                   0
# SibSp                 0
#                      ..
# Ticket_W./C. 6607     0
# Ticket_W./C. 6608     0
# Ticket_W.E.P. 5734    0
# Embarked_Q            0
# Embarked_S            0
# Length: 789, dtype: int64

# %%
scaler = StandardScaler()
df[df.columns] = scaler.fit_transform(df)

# %%
df
# Out:
#      PassengerId  Survived    Pclass       Age     SibSp     Parch      Fare  \
# 0      -1.727912 -0.755929  0.873482  0.386231 -0.499470 -0.400248 -0.497413
# 1      -1.719625  1.322876  0.873482  1.371370  0.616992 -0.400248 -0.512278
# 2      -1.711337 -0.755929 -0.315819  2.553537 -0.499470 -0.400248 -0.464100
# 3      -1.703050 -0.755929  0.873482 -0.204852 -0.499470 -0.400248 -0.482475
# 4      -1.694763  1.322876  0.873482 -0.598908  0.616992  0.619896 -0.417492
# ..           ...       ...       ...       ...       ...       ...       ...
# 413     1.694763 -0.755929  0.873482 -0.204852 -0.499470 -0.400248 -0.493455
# 414     1.703050  1.322876 -1.505120  0.740881 -0.499470 -0.400248  1.314435
# 415     1.711337 -0.755929  0.873482  0.701476 -0.499470 -0.400248 -0.507796
# 416     1.719625 -0.755929  0.873482 -0.204852 -0.499470 -0.400248 -0.493455
# 417     1.727912 -0.755929  0.873482 -0.204852  0.616992  0.619896 -0.236957
#
#      Name_Abelseth, Miss. Karen Marie  Name_Abelseth, Mr. Olaus Jorgensen  \
# 0                            -0.04897                            -0.04897
# 1                            -0.04897                            -0.04897
# 2                            -0.04897                            -0.04897
# 3                            -0.04897                            -0.04897
# 4                            -0.04897                            -0.04897
# ..                                ...                                 ...
# 413                          -0.04897                            -0.04897
# 414                          -0.04897                            -0.04897
# 415                          -0.04897                            -0.04897
# 416                          -0.04897                            -0.04897
# 417                          -0.04897                            -0.04897
#
#      Name_Abrahamsson, Mr. Abraham August Johannes  ...  \
# 0                                         -0.04897  ...
# 1                                         -0.04897  ...
# 2                                         -0.04897  ...
# 3                                         -0.04897  ...
# 4                                         -0.04897  ...
# ..                                             ...  ...
# 413                                       -0.04897  ...
# 414                                       -0.04897  ...
# 415                                       -0.04897  ...
# 416                                       -0.04897  ...
# 417                                       -0.04897  ...
#
#      Ticket_STON/O 2. 3101291  Ticket_STON/O2. 3101270  \
# 0                    -0.04897                 -0.04897
# 1                    -0.04897                 -0.04897
# 2                    -0.04897                 -0.04897
# 3                    -0.04897                 -0.04897
# 4                    -0.04897                 -0.04897
# ..                        ...                      ...
# 413                  -0.04897                 -0.04897
# 414                  -0.04897                 -0.04897
# 415                  -0.04897                 -0.04897
# 416                  -0.04897                 -0.04897
# 417                  -0.04897                 -0.04897
#
#      Ticket_STON/OQ. 369943  Ticket_W./C. 14260  Ticket_W./C. 14266  \
# 0                  -0.04897            -0.04897            -0.04897
# 1                  -0.04897            -0.04897            -0.04897
# 2                  -0.04897            -0.04897            -0.04897
# 3                  -0.04897            -0.04897            -0.04897
# 4                  -0.04897            -0.04897            -0.04897
# ..                      ...                 ...                 ...
# 413                -0.04897            -0.04897            -0.04897
# 414                -0.04897            -0.04897            -0.04897
# 415                -0.04897            -0.04897            -0.04897
# 416                -0.04897            -0.04897            -0.04897
# 417                -0.04897            -0.04897            -0.04897
#
#      Ticket_W./C. 6607  Ticket_W./C. 6608  Ticket_W.E.P. 5734  Embarked_Q  \
# 0            -0.069338           -0.04897            -0.04897    2.843757
# 1            -0.069338           -0.04897            -0.04897   -0.351647
# 2            -0.069338           -0.04897            -0.04897    2.843757
# 3            -0.069338           -0.04897            -0.04897   -0.351647
# 4            -0.069338           -0.04897            -0.04897   -0.351647
# ..                 ...                ...                 ...         ...
# 413          -0.069338           -0.04897            -0.04897   -0.351647
# 414          -0.069338           -0.04897            -0.04897   -0.351647
# 415          -0.069338           -0.04897            -0.04897   -0.351647
# 416          -0.069338           -0.04897            -0.04897   -0.351647
# 417          -0.069338           -0.04897            -0.04897   -0.351647
#
#      Embarked_S
# 0     -1.350676
# 1      0.740370
# 2     -1.350676
# 3      0.740370
# 4      0.740370
# ..          ...
# 413    0.740370
# 414   -1.350676
# 415    0.740370
# 416    0.740370
# 417   -1.350676
#
# [418 rows x 789 columns]
